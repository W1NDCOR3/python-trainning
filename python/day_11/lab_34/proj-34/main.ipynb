# %%
import pandas as pd
import seaborn as sns


csv_file_path = r"C:\Users\FORMACAO\Documents\this_is_the_repo\python-trainning\python\day_10\examples\simple_pandas\inputs\employees.csv"


# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

sns.set_theme()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 11
#       8 # Read the CSV file into a DataFrame
#       9 df = pd.read_csv(csv_file_path)
# ---> 11 sns.set_theme()
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1428, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1533, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1905, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File c:\Users\FORMACAO\AppData\Local\Programs\Python\Python312\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2197, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2194             from_this_thread.append(frame_custom_thread_id)
#    2196     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2197         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2199 frames_list = None
#    2201 if keep_suspended:
#    2202     # This means that we should pause again after a set next statement.
#
# File c:\Users\FORMACAO\AppData\Local\Programs\Python\Python312\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2266, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2263                 queue.put(internal_cmd)
#    2264                 wait_timeout = TIMEOUT_FAST
# -> 2266         notify_event.wait(wait_timeout)
#    2267         notify_event.clear()
#    2269 finally:
#
# File c:\Users\FORMACAO\AppData\Local\Programs\Python\Python312\Lib\threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File c:\Users\FORMACAO\AppData\Local\Programs\Python\Python312\Lib\threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
df['Salary'].plot(kind='hist')
df['Salary'].plot(kind='box')
df['Salary'].plot(kind='bar')
df.groupby('Department')['Salary'].sum().plot(kind='bar')
df.groupby('Department')['Salary'].sum().plot(kind='pie')
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
df['Salary'].plot(kind='hist').get_figure().savefig('histogram.png')
df['Salary'].plot(kind='box').get_figure().savefig('boxplot.png')
df['Salary'].plot(kind='bar').get_figure().savefig('bar_chart.png')

df.groupby('Department')['Salary'].sum().plot(kind='bar').get_figure().savefig('grouped_bar_chart.png')
df.groupby('Department')['Salary'].sum().plot(kind='pie').get_figure().savefig('grouped_pie_chart.png')

# %%
sns.heatmap(df[['Salary', 'Age']].corr(), annot=True)
sns.heatmap(df[['Salary', 'Age']].corr(), annot=True).get_figure().savefig('heatmap.png')
